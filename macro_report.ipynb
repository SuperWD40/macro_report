# %%
# %%html
# <style>
# .cell-output-ipywidget-background {
#     background-color: transparent !important;
# }
# :root {
#     --jp-widgets-color: var(--vscode-editor-foreground);
#     --jp-widgets-font-size: var(--vscode-editor-font-size);
# }
# </style>
# Out:
# <style>
# .cell-output-ipywidget-background {
#     background-color: transparent !important;
# }
# :root {
#     --jp-widgets-color: var(--vscode-editor-foreground);
#     --jp-widgets-font-size: var(--vscode-editor-font-size);
# }
# </style>

# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import yfinance as yf
from yield_curve import yield_curve
from top_n_flop import top_n_flop
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
allocation_df = pd.read_csv('index_allocation.csv', index_col='Ticker')
market_df = yf.Ticker('^FCHI').history('max')['Close']
market_df = market_df.tz_localize(None)
history_df = pd.DataFrame()
for ticker in allocation_df.index:
    history_df[ticker] = yf.Ticker(ticker).history('max')['Close']
history_df = history_df.tz_localize(None)

# %%
top_n_flop(history_df).show()
# Out:
# interactive(children=(Select(description='range', index=2, options=('1D', '1W', '1M', '3M', '6M', 'YTD', '1Y',…

# %%
yield_curve().show()
# Out:
# interactive(children=(Select(description='Treasury:', index=1, options=('FR', 'US'), value='US'), SelectMultip…

# %%
# %run market_climate
